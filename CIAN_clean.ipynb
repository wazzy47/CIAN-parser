# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def getPrice(flat_page):
    price = flat_page.find('div', attrs={'class':'object_descr_price'})
    price = re.split('<div>|руб|\W', str(price))
    price = "".join([i for i in price if i.isdigit()][-3:])
    return int(price)

# %%
def getCoords(flat_page):
    coords = flat_page.find('div', attrs={'class':'map_info_button_extend'}).contents[1]
    coords = re.split('&amp|center=|%2C', str(coords))
    coords_list = []
    for item in coords:
        if item[0].isdigit():
            coords_list.append(item)
    lat = float(coords_list[0])
    lon = float(coords_list[1])
    return lat, lon

# %%
def getRoom(flat_page):
    rooms = flat_page.find('div', attrs={'class':'object_descr_title'})
    rooms = html_stripper(rooms)
    room_number = ''
    for i in re.split('-|\n', rooms):
        if 'комн' in i:
            break
        else:
            room_number += i
    room_number = "".join(room_number.split())
    return room_number

# %%
def getWalk(flat_page):
    walkm = flat_page.find('span', attrs={'class':'object_item_metro_comment'})
    if "пешком" in str(walkm):
        return 1
    else:
        return 0

# %%
def getS(table):
    return float((re.split('площадь:\n\n|м2', table)[1]).replace(",", "."))

# %%
def getLivingS(table):
    return float(re.split('Жилая площадь:\n\n|м2\n\n\n\nПлощадь кухни', table)[1].replace(",", "."))

# %%
def getKitchenS(table):
    return float(re.split("кухни:\n\n|Балкон", table)[1][0].replace("–","0"))

# %%
def getTel(table):
    if re.split('Телефон:\n|\n\n\nВид', table)[1]=='нет':
        return 0 
    else:
        return 1

# %%
def getNew(table):
    if ((re.split('Тип дома:\n\n|, \n', table)[1]).find('вторичка') >= 0):
        return 0
    else:
        return 1

# %%
def getBrick(table):
    if (table.find('кирп')!=-1 or table.find('жб')!=-1 or table.find('монолит')!=-1):
        return 1
    else:
        return 0

# %%
def getMetrDist(flat_page):
    walkm = str(flat_page.find('span', attrs={'class':'object_item_metro_comment'}))
    return float(re.sub("\D", "", walkm))

# %%
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    #Calculate the great circle distance between two points 
    #on the earth (specified in decimal degrees)
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km*1000.0

def getDist(lat1, lon1):
    centreLat = 55.75370903771494 
    centreLon = 37.61981338262558 
    return haversine(lon1, lat1, centreLon, centreLat)

# %%
def getBallod(table):
    ballod = re.split('Балкон:\n|\n\n\nЛифт', table)[1]
    if ballod.find('бал')!=-1 or ballod.find('лод')!=-1:
        return 1
    else:
        return 0

# %%
def getFloorAndTotalFloor(table):
    strtoint = re.split('Этаж|Тип', table)[1]
    full_pattern = re.compile('[^0-9\\\/]|_')
    strtoint = re.sub(full_pattern, '', strtoint)
    return list(map(int, strtoint.split('/')))

# %%
def html_stripper(text):
    return re.sub('<[^<]+?>', '', str(text))

# %%
orehovo = 'http://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=95&engine_version=2&offer_type=flat&p={}'

# %%
links = []
for page in range(1, 30):
    page_url =  orehovo.format(page)

    search_page = requests.get(page_url)
    search_page = search_page.content
    search_page = BeautifulSoup(search_page, 'lxml')

    flat_urls = search_page.findAll('div', attrs = {'ng-class':"{'serp-item_removed': offer.remove.state, 'serp-item_popup-opened': isPopupOpen}"})
    flat_urls = re.split('http://www.cian.ru/sale/flat/|/" ng-class="', str(flat_urls))

    for link in flat_urls:
        if link.isdigit():
            links.append(link)

# %%
flats = []
errors = []
for i in range(0, len(links)):
    try:
        flat_url = 'http://www.cian.ru/sale/flat/' + str(links[i]) + '/'
        print(flat_url)
        flat_page = requests.get(flat_url)
        flat_page = flat_page.content
        flat_page = BeautifulSoup(flat_page, 'lxml')
        table = flat_page.find('table', attrs = {'class':'object_descr_props'})
        table = html_stripper(table)
        flatStats = {'district':'Orekhovo-Borisovo Yuzhnoye'}
        flatStats['N'] = i
        flatStats['Rooms'] = getRoom(flat_page)
        flatStats['Price'] = getPrice(flat_page) 
        flatStats['Totsp'] = getS(table)
        flatStats['Livsp'] = getLivingS(table)
        flatStats['Kitsp'] = getKitchenS(table)
        flatStats['Metrdist'] = getMetrDist(flat_page)
        flatStats['Walk'] = getWalk(flat_page)
        flatStats['Brick'] = getBrick(table)
        flatStats['Tel'] = getTel(table)
        flatStats['Bal'] = getBallod(table)
        flatStats['Floor'] = getFloorAndTotalFloor(table)[0]
        flatStats['Nfloors'] = getFloorAndTotalFloor(table)[1]
        flatStats['New'] = getNew(table)
        coords = getCoords(flat_page)
        flatStats['Dist'] = getDist(coords[0], coords[1])
        flats.append(flatStats.copy())
    except:
        print("Error at " +flat_url)
        errors.append(flat_url)
# Out:
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/141527552/
# http://www.cian.ru/sale/flat/150703591/
# http://www.cian.ru/sale/flat/51252264/
# http://www.cian.ru/sale/flat/51250999/
# http://www.cian.ru/sale/flat/51251559/
# http://www.cian.ru/sale/flat/150924306/
# http://www.cian.ru/sale/flat/147494757/
# http://www.cian.ru/sale/flat/149429092/
# http://www.cian.ru/sale/flat/147898966/
# http://www.cian.ru/sale/flat/148566952/
# http://www.cian.ru/sale/flat/51251534/
# http://www.cian.ru/sale/flat/149341092/
# http://www.cian.ru/sale/flat/150456303/
# http://www.cian.ru/sale/flat/150226105/
# http://www.cian.ru/sale/flat/150855351/
# http://www.cian.ru/sale/flat/149837534/
# http://www.cian.ru/sale/flat/149016772/
# http://www.cian.ru/sale/flat/151080346/
# http://www.cian.ru/sale/flat/149580164/
# http://www.cian.ru/sale/flat/149595900/
# http://www.cian.ru/sale/flat/149352714/
# http://www.cian.ru/sale/flat/149482802/
# http://www.cian.ru/sale/flat/149858198/
# http://www.cian.ru/sale/flat/144032811/
# http://www.cian.ru/sale/flat/149352590/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/149352738/
# http://www.cian.ru/sale/flat/149352608/
# http://www.cian.ru/sale/flat/149672065/
# http://www.cian.ru/sale/flat/149352492/
# http://www.cian.ru/sale/flat/151073211/
# http://www.cian.ru/sale/flat/149352503/
# http://www.cian.ru/sale/flat/149352679/
# http://www.cian.ru/sale/flat/150355841/
# http://www.cian.ru/sale/flat/150331635/
# http://www.cian.ru/sale/flat/151110409/
# http://www.cian.ru/sale/flat/32776288/
# http://www.cian.ru/sale/flat/141318900/
# http://www.cian.ru/sale/flat/148862969/
# http://www.cian.ru/sale/flat/148796083/
# http://www.cian.ru/sale/flat/15075556/
# http://www.cian.ru/sale/flat/147859887/
# http://www.cian.ru/sale/flat/151009410/
# http://www.cian.ru/sale/flat/148074657/
# http://www.cian.ru/sale/flat/150856398/
# http://www.cian.ru/sale/flat/150921701/
# http://www.cian.ru/sale/flat/150596428/
# http://www.cian.ru/sale/flat/148710078/
# http://www.cian.ru/sale/flat/46767272/
# http://www.cian.ru/sale/flat/143147018/
# http://www.cian.ru/sale/flat/149352435/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/149352617/
# http://www.cian.ru/sale/flat/51251354/
# http://www.cian.ru/sale/flat/149352533/
# http://www.cian.ru/sale/flat/149225843/
# http://www.cian.ru/sale/flat/149352644/
# http://www.cian.ru/sale/flat/149331099/
# http://www.cian.ru/sale/flat/149352555/
# http://www.cian.ru/sale/flat/150638412/
# http://www.cian.ru/sale/flat/149352789/
# http://www.cian.ru/sale/flat/150278345/
# http://www.cian.ru/sale/flat/151082653/
# http://www.cian.ru/sale/flat/28467100/
# http://www.cian.ru/sale/flat/149352798/
# http://www.cian.ru/sale/flat/150743409/
# http://www.cian.ru/sale/flat/151072588/
# http://www.cian.ru/sale/flat/149369076/
# http://www.cian.ru/sale/flat/151081790/
# http://www.cian.ru/sale/flat/144912092/
# http://www.cian.ru/sale/flat/150564222/
# http://www.cian.ru/sale/flat/150834841/
# http://www.cian.ru/sale/flat/45055295/
# http://www.cian.ru/sale/flat/149352729/
# http://www.cian.ru/sale/flat/149672030/
# http://www.cian.ru/sale/flat/150299640/
# http://www.cian.ru/sale/flat/149352494/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150383078/
# http://www.cian.ru/sale/flat/150383079/
# http://www.cian.ru/sale/flat/150274434/
# http://www.cian.ru/sale/flat/151041041/
# http://www.cian.ru/sale/flat/149389978/
# http://www.cian.ru/sale/flat/151029785/
# http://www.cian.ru/sale/flat/150254329/
# http://www.cian.ru/sale/flat/140924005/
# http://www.cian.ru/sale/flat/151097893/
# http://www.cian.ru/sale/flat/150819226/
# http://www.cian.ru/sale/flat/147431567/
# http://www.cian.ru/sale/flat/149420273/
# http://www.cian.ru/sale/flat/149127470/
# http://www.cian.ru/sale/flat/150639746/
# http://www.cian.ru/sale/flat/150639745/
# http://www.cian.ru/sale/flat/150639747/
# http://www.cian.ru/sale/flat/142858602/
# http://www.cian.ru/sale/flat/149199689/
# http://www.cian.ru/sale/flat/151095581/
# http://www.cian.ru/sale/flat/147593981/
# http://www.cian.ru/sale/flat/150346431/
# http://www.cian.ru/sale/flat/150276489/
# http://www.cian.ru/sale/flat/148860196/
# http://www.cian.ru/sale/flat/149352901/
# http://www.cian.ru/sale/flat/151094412/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/151091966/
# http://www.cian.ru/sale/flat/149739211/
# http://www.cian.ru/sale/flat/150855657/
# http://www.cian.ru/sale/flat/148460015/
# http://www.cian.ru/sale/flat/150438742/
# http://www.cian.ru/sale/flat/149381964/
# http://www.cian.ru/sale/flat/149729871/
# http://www.cian.ru/sale/flat/150692693/
# http://www.cian.ru/sale/flat/151098739/
# http://www.cian.ru/sale/flat/149773530/
# http://www.cian.ru/sale/flat/150869658/
# http://www.cian.ru/sale/flat/137385457/
# http://www.cian.ru/sale/flat/150505818/
# http://www.cian.ru/sale/flat/151089202/
# http://www.cian.ru/sale/flat/148562477/
# http://www.cian.ru/sale/flat/141808750/
# http://www.cian.ru/sale/flat/141223255/
# http://www.cian.ru/sale/flat/149113297/
# http://www.cian.ru/sale/flat/151091345/
# http://www.cian.ru/sale/flat/149823214/
# http://www.cian.ru/sale/flat/147835305/
# http://www.cian.ru/sale/flat/148997636/
# http://www.cian.ru/sale/flat/150369935/
# http://www.cian.ru/sale/flat/149936203/
# http://www.cian.ru/sale/flat/149352716/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/147431627/
# http://www.cian.ru/sale/flat/150576676/
# Error at http://www.cian.ru/sale/flat/150576676/
# http://www.cian.ru/sale/flat/150185631/
# http://www.cian.ru/sale/flat/150863334/
# http://www.cian.ru/sale/flat/150701139/
# http://www.cian.ru/sale/flat/149091733/
# http://www.cian.ru/sale/flat/151091675/
# http://www.cian.ru/sale/flat/150568457/
# http://www.cian.ru/sale/flat/150659366/
# http://www.cian.ru/sale/flat/149535128/
# http://www.cian.ru/sale/flat/49844428/
# http://www.cian.ru/sale/flat/149352453/
# http://www.cian.ru/sale/flat/42811080/
# http://www.cian.ru/sale/flat/149403456/
# http://www.cian.ru/sale/flat/151093363/
# http://www.cian.ru/sale/flat/150443860/
# http://www.cian.ru/sale/flat/149582373/
# http://www.cian.ru/sale/flat/139149975/
# http://www.cian.ru/sale/flat/149660239/
# http://www.cian.ru/sale/flat/150221555/
# http://www.cian.ru/sale/flat/149352452/
# http://www.cian.ru/sale/flat/150435078/
# http://www.cian.ru/sale/flat/147921596/
# http://www.cian.ru/sale/flat/11980864/
# http://www.cian.ru/sale/flat/150228872/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/151092496/
# http://www.cian.ru/sale/flat/149614895/
# http://www.cian.ru/sale/flat/47574507/
# http://www.cian.ru/sale/flat/149672098/
# http://www.cian.ru/sale/flat/149352795/
# http://www.cian.ru/sale/flat/151097188/
# http://www.cian.ru/sale/flat/151092534/
# http://www.cian.ru/sale/flat/149607728/
# http://www.cian.ru/sale/flat/36461938/
# http://www.cian.ru/sale/flat/150352207/
# http://www.cian.ru/sale/flat/150865400/
# http://www.cian.ru/sale/flat/150608957/
# http://www.cian.ru/sale/flat/148992951/
# http://www.cian.ru/sale/flat/151091656/
# http://www.cian.ru/sale/flat/150997231/
# http://www.cian.ru/sale/flat/150961494/
# http://www.cian.ru/sale/flat/150383081/
# http://www.cian.ru/sale/flat/149980846/
# http://www.cian.ru/sale/flat/148052591/
# http://www.cian.ru/sale/flat/151092432/
# http://www.cian.ru/sale/flat/150270661/
# http://www.cian.ru/sale/flat/148811244/
# http://www.cian.ru/sale/flat/144325583/
# http://www.cian.ru/sale/flat/32134570/
# http://www.cian.ru/sale/flat/151036693/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/149434016/
# http://www.cian.ru/sale/flat/150660576/
# http://www.cian.ru/sale/flat/47151487/
# http://www.cian.ru/sale/flat/51251694/
# http://www.cian.ru/sale/flat/149604857/
# http://www.cian.ru/sale/flat/149615104/
# http://www.cian.ru/sale/flat/150862233/
# http://www.cian.ru/sale/flat/149016780/
# http://www.cian.ru/sale/flat/149556672/
# http://www.cian.ru/sale/flat/150265821/
# http://www.cian.ru/sale/flat/151017073/
# http://www.cian.ru/sale/flat/150372740/
# http://www.cian.ru/sale/flat/28240444/
# http://www.cian.ru/sale/flat/149283670/
# http://www.cian.ru/sale/flat/150857497/
# http://www.cian.ru/sale/flat/150596021/
# http://www.cian.ru/sale/flat/150681938/
# http://www.cian.ru/sale/flat/150078584/
# http://www.cian.ru/sale/flat/151116041/
# http://www.cian.ru/sale/flat/149569264/
# http://www.cian.ru/sale/flat/51251689/
# http://www.cian.ru/sale/flat/151094107/
# http://www.cian.ru/sale/flat/148817434/
# http://www.cian.ru/sale/flat/150375020/
# http://www.cian.ru/sale/flat/149640479/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/147438751/
# http://www.cian.ru/sale/flat/149336269/
# http://www.cian.ru/sale/flat/150615989/
# http://www.cian.ru/sale/flat/149127712/
# http://www.cian.ru/sale/flat/150714835/
# http://www.cian.ru/sale/flat/150888858/
# http://www.cian.ru/sale/flat/149284034/
# http://www.cian.ru/sale/flat/148111996/
# http://www.cian.ru/sale/flat/151094499/
# http://www.cian.ru/sale/flat/149384423/
# http://www.cian.ru/sale/flat/148780778/
# http://www.cian.ru/sale/flat/150474680/
# http://www.cian.ru/sale/flat/147565590/
# http://www.cian.ru/sale/flat/150465575/
# http://www.cian.ru/sale/flat/51251079/
# http://www.cian.ru/sale/flat/149872680/
# http://www.cian.ru/sale/flat/150454510/
# http://www.cian.ru/sale/flat/150936498/
# http://www.cian.ru/sale/flat/151121512/
# http://www.cian.ru/sale/flat/148866558/
# http://www.cian.ru/sale/flat/149013795/
# http://www.cian.ru/sale/flat/149783651/
# http://www.cian.ru/sale/flat/150574978/
# http://www.cian.ru/sale/flat/150780217/
# http://www.cian.ru/sale/flat/44435214/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/12611569/
# http://www.cian.ru/sale/flat/150869004/
# http://www.cian.ru/sale/flat/151094160/
# http://www.cian.ru/sale/flat/151091851/
# http://www.cian.ru/sale/flat/144395591/
# http://www.cian.ru/sale/flat/148653389/
# http://www.cian.ru/sale/flat/30565462/
# http://www.cian.ru/sale/flat/149540808/
# http://www.cian.ru/sale/flat/151031192/
# http://www.cian.ru/sale/flat/151090284/
# http://www.cian.ru/sale/flat/150898332/
# http://www.cian.ru/sale/flat/141307454/
# http://www.cian.ru/sale/flat/140493525/
# http://www.cian.ru/sale/flat/150137959/
# http://www.cian.ru/sale/flat/148935734/
# http://www.cian.ru/sale/flat/3477139/
# http://www.cian.ru/sale/flat/150384180/
# http://www.cian.ru/sale/flat/51251934/
# http://www.cian.ru/sale/flat/151092976/
# http://www.cian.ru/sale/flat/148661114/
# http://www.cian.ru/sale/flat/150932395/
# http://www.cian.ru/sale/flat/151092367/
# http://www.cian.ru/sale/flat/150949541/
# http://www.cian.ru/sale/flat/151097458/
# http://www.cian.ru/sale/flat/44035920/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/149563743/
# http://www.cian.ru/sale/flat/150491107/
# http://www.cian.ru/sale/flat/150100241/
# http://www.cian.ru/sale/flat/147551091/
# http://www.cian.ru/sale/flat/151092199/
# http://www.cian.ru/sale/flat/148195989/
# http://www.cian.ru/sale/flat/148086943/
# http://www.cian.ru/sale/flat/146656243/
# http://www.cian.ru/sale/flat/25940080/
# http://www.cian.ru/sale/flat/150709160/
# http://www.cian.ru/sale/flat/147597124/
# http://www.cian.ru/sale/flat/150429583/
# http://www.cian.ru/sale/flat/149352432/
# http://www.cian.ru/sale/flat/149352514/
# http://www.cian.ru/sale/flat/150473692/
# http://www.cian.ru/sale/flat/46995144/
# http://www.cian.ru/sale/flat/149780166/
# http://www.cian.ru/sale/flat/150820052/
# http://www.cian.ru/sale/flat/149594325/
# http://www.cian.ru/sale/flat/149525138/
# http://www.cian.ru/sale/flat/149618560/
# http://www.cian.ru/sale/flat/150931567/
# http://www.cian.ru/sale/flat/147735907/
# http://www.cian.ru/sale/flat/26879782/
# http://www.cian.ru/sale/flat/39101753/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/151091653/
# http://www.cian.ru/sale/flat/149389998/
# http://www.cian.ru/sale/flat/148414858/
# http://www.cian.ru/sale/flat/150299649/
# http://www.cian.ru/sale/flat/149207918/
# http://www.cian.ru/sale/flat/42683142/
# http://www.cian.ru/sale/flat/149039718/
# http://www.cian.ru/sale/flat/151031196/
# http://www.cian.ru/sale/flat/149566264/
# http://www.cian.ru/sale/flat/150892689/
# http://www.cian.ru/sale/flat/150648318/
# http://www.cian.ru/sale/flat/38738015/
# http://www.cian.ru/sale/flat/149280067/
# http://www.cian.ru/sale/flat/150239184/
# Error at http://www.cian.ru/sale/flat/150239184/
# http://www.cian.ru/sale/flat/150464744/
# http://www.cian.ru/sale/flat/141245454/
# http://www.cian.ru/sale/flat/39399347/
# http://www.cian.ru/sale/flat/28009498/
# http://www.cian.ru/sale/flat/151094632/
# http://www.cian.ru/sale/flat/150124714/
# http://www.cian.ru/sale/flat/145463484/
# http://www.cian.ru/sale/flat/148179449/
# http://www.cian.ru/sale/flat/149512110/
# http://www.cian.ru/sale/flat/51251804/
# http://www.cian.ru/sale/flat/149352596/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/149352649/
# http://www.cian.ru/sale/flat/151096339/
# http://www.cian.ru/sale/flat/151090706/
# http://www.cian.ru/sale/flat/150643246/
# Error at http://www.cian.ru/sale/flat/150643246/
# http://www.cian.ru/sale/flat/145259079/
# http://www.cian.ru/sale/flat/148042010/
# http://www.cian.ru/sale/flat/151004701/
# http://www.cian.ru/sale/flat/149609171/
# http://www.cian.ru/sale/flat/150916929/
# http://www.cian.ru/sale/flat/150640395/
# http://www.cian.ru/sale/flat/150201433/
# http://www.cian.ru/sale/flat/149352751/
# http://www.cian.ru/sale/flat/148740845/
# http://www.cian.ru/sale/flat/149793088/
# http://www.cian.ru/sale/flat/149352645/
# http://www.cian.ru/sale/flat/150221575/
# http://www.cian.ru/sale/flat/150978478/
# http://www.cian.ru/sale/flat/147695428/
# http://www.cian.ru/sale/flat/150639907/
# http://www.cian.ru/sale/flat/151098647/
# http://www.cian.ru/sale/flat/150080258/
# http://www.cian.ru/sale/flat/149687103/
# http://www.cian.ru/sale/flat/33465670/
# http://www.cian.ru/sale/flat/151098499/
# http://www.cian.ru/sale/flat/151094246/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/150486526/
# http://www.cian.ru/sale/flat/149751167/
# http://www.cian.ru/sale/flat/139846539/
# http://www.cian.ru/sale/flat/150847449/
# http://www.cian.ru/sale/flat/151094140/
# http://www.cian.ru/sale/flat/148835757/
# http://www.cian.ru/sale/flat/24817402/
# http://www.cian.ru/sale/flat/150171483/
# http://www.cian.ru/sale/flat/150324139/
# http://www.cian.ru/sale/flat/151096495/
# http://www.cian.ru/sale/flat/150597355/
# http://www.cian.ru/sale/flat/138445941/
# http://www.cian.ru/sale/flat/149528245/
# http://www.cian.ru/sale/flat/148075793/
# http://www.cian.ru/sale/flat/149862586/
# http://www.cian.ru/sale/flat/139996466/
# http://www.cian.ru/sale/flat/50900568/
# http://www.cian.ru/sale/flat/147512237/
# http://www.cian.ru/sale/flat/149931459/
# http://www.cian.ru/sale/flat/151089261/
# http://www.cian.ru/sale/flat/151093330/
# http://www.cian.ru/sale/flat/150972242/
# http://www.cian.ru/sale/flat/151095037/
# http://www.cian.ru/sale/flat/151090472/
# http://www.cian.ru/sale/flat/148816381/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/148920405/
# http://www.cian.ru/sale/flat/150458484/
# http://www.cian.ru/sale/flat/151112501/
# http://www.cian.ru/sale/flat/49820868/
# http://www.cian.ru/sale/flat/148154449/
# http://www.cian.ru/sale/flat/150532268/
# http://www.cian.ru/sale/flat/149461529/
# http://www.cian.ru/sale/flat/148928286/
# http://www.cian.ru/sale/flat/150649073/
# http://www.cian.ru/sale/flat/150821426/
# http://www.cian.ru/sale/flat/149352463/
# http://www.cian.ru/sale/flat/150535333/
# http://www.cian.ru/sale/flat/147257040/
# http://www.cian.ru/sale/flat/49568172/
# http://www.cian.ru/sale/flat/147429603/
# http://www.cian.ru/sale/flat/149162118/
# http://www.cian.ru/sale/flat/150228336/
# http://www.cian.ru/sale/flat/33488488/
# http://www.cian.ru/sale/flat/4395018/
# http://www.cian.ru/sale/flat/149352742/
# http://www.cian.ru/sale/flat/149948069/
# http://www.cian.ru/sale/flat/49066956/
# http://www.cian.ru/sale/flat/39294053/
# http://www.cian.ru/sale/flat/149061731/
# http://www.cian.ru/sale/flat/150843652/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/151115706/
# http://www.cian.ru/sale/flat/23552064/
# http://www.cian.ru/sale/flat/150852584/
# http://www.cian.ru/sale/flat/150582053/
# http://www.cian.ru/sale/flat/149352688/
# http://www.cian.ru/sale/flat/150907061/
# http://www.cian.ru/sale/flat/149891591/
# http://www.cian.ru/sale/flat/149352792/
# http://www.cian.ru/sale/flat/151090581/
# http://www.cian.ru/sale/flat/150193202/
# http://www.cian.ru/sale/flat/150858163/
# http://www.cian.ru/sale/flat/149801207/
# http://www.cian.ru/sale/flat/147492381/
# http://www.cian.ru/sale/flat/49688343/
# http://www.cian.ru/sale/flat/136883222/
# http://www.cian.ru/sale/flat/150701138/
# http://www.cian.ru/sale/flat/149846559/
# http://www.cian.ru/sale/flat/150804010/
# http://www.cian.ru/sale/flat/49428401/
# http://www.cian.ru/sale/flat/150973876/
# http://www.cian.ru/sale/flat/149239983/
# http://www.cian.ru/sale/flat/150971941/
# http://www.cian.ru/sale/flat/148425028/
# http://www.cian.ru/sale/flat/150298752/
# http://www.cian.ru/sale/flat/149673201/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/148378735/
# http://www.cian.ru/sale/flat/151003877/
# http://www.cian.ru/sale/flat/147306744/
# http://www.cian.ru/sale/flat/146882043/
# http://www.cian.ru/sale/flat/149288528/
# http://www.cian.ru/sale/flat/150418504/
# http://www.cian.ru/sale/flat/149321331/
# http://www.cian.ru/sale/flat/149700952/
# http://www.cian.ru/sale/flat/150301859/
# http://www.cian.ru/sale/flat/150976712/
# http://www.cian.ru/sale/flat/151077604/
# http://www.cian.ru/sale/flat/49578468/
# http://www.cian.ru/sale/flat/150390704/
# http://www.cian.ru/sale/flat/150865270/
# http://www.cian.ru/sale/flat/151110622/
# http://www.cian.ru/sale/flat/149976486/
# http://www.cian.ru/sale/flat/51220544/
# http://www.cian.ru/sale/flat/139955818/
# http://www.cian.ru/sale/flat/42759300/
# http://www.cian.ru/sale/flat/149663077/
# http://www.cian.ru/sale/flat/149405299/
# http://www.cian.ru/sale/flat/47062059/
# http://www.cian.ru/sale/flat/150807657/
# http://www.cian.ru/sale/flat/148125833/
# http://www.cian.ru/sale/flat/150855650/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/150989881/
# http://www.cian.ru/sale/flat/145139914/
# http://www.cian.ru/sale/flat/150615741/
# http://www.cian.ru/sale/flat/150277183/
# http://www.cian.ru/sale/flat/146664447/
# http://www.cian.ru/sale/flat/150317031/
# http://www.cian.ru/sale/flat/145833237/
# http://www.cian.ru/sale/flat/149307022/
# http://www.cian.ru/sale/flat/30124432/
# http://www.cian.ru/sale/flat/151000462/
# http://www.cian.ru/sale/flat/149596249/
# http://www.cian.ru/sale/flat/150437729/
# http://www.cian.ru/sale/flat/148122733/
# http://www.cian.ru/sale/flat/147867292/
# http://www.cian.ru/sale/flat/150832568/
# http://www.cian.ru/sale/flat/150870726/
# http://www.cian.ru/sale/flat/148955985/
# http://www.cian.ru/sale/flat/149689219/
# http://www.cian.ru/sale/flat/149126070/
# http://www.cian.ru/sale/flat/147636878/
# http://www.cian.ru/sale/flat/143458553/
# http://www.cian.ru/sale/flat/150453342/
# http://www.cian.ru/sale/flat/150122668/
# http://www.cian.ru/sale/flat/35486718/
# http://www.cian.ru/sale/flat/148998219/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/149551150/
# http://www.cian.ru/sale/flat/148295823/
# http://www.cian.ru/sale/flat/149426969/
# http://www.cian.ru/sale/flat/150574613/
# http://www.cian.ru/sale/flat/151139851/
# http://www.cian.ru/sale/flat/147362251/
# http://www.cian.ru/sale/flat/149241509/
# http://www.cian.ru/sale/flat/150554781/
# http://www.cian.ru/sale/flat/148339230/
# http://www.cian.ru/sale/flat/150263778/
# http://www.cian.ru/sale/flat/149565768/
# http://www.cian.ru/sale/flat/150660725/
# http://www.cian.ru/sale/flat/151054827/
# http://www.cian.ru/sale/flat/140081856/
# http://www.cian.ru/sale/flat/149806014/
# http://www.cian.ru/sale/flat/147948079/
# http://www.cian.ru/sale/flat/148784228/
# http://www.cian.ru/sale/flat/150712429/
# http://www.cian.ru/sale/flat/146301390/
# http://www.cian.ru/sale/flat/150334927/
# http://www.cian.ru/sale/flat/28396540/
# http://www.cian.ru/sale/flat/148672612/
# http://www.cian.ru/sale/flat/149716269/
# http://www.cian.ru/sale/flat/150989828/
# http://www.cian.ru/sale/flat/151015413/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/151065153/
# http://www.cian.ru/sale/flat/150957362/
# http://www.cian.ru/sale/flat/151021387/
# http://www.cian.ru/sale/flat/151071223/
# http://www.cian.ru/sale/flat/146558092/
# http://www.cian.ru/sale/flat/150684225/
# http://www.cian.ru/sale/flat/150948395/
# http://www.cian.ru/sale/flat/150681236/
# http://www.cian.ru/sale/flat/148961596/
# http://www.cian.ru/sale/flat/149389559/
# http://www.cian.ru/sale/flat/151076462/
# http://www.cian.ru/sale/flat/151077950/
# http://www.cian.ru/sale/flat/150196306/
# http://www.cian.ru/sale/flat/49472045/
# http://www.cian.ru/sale/flat/151072104/
# http://www.cian.ru/sale/flat/144870897/
# http://www.cian.ru/sale/flat/147310836/
# http://www.cian.ru/sale/flat/145248474/
# http://www.cian.ru/sale/flat/150867183/
# http://www.cian.ru/sale/flat/147461998/
# http://www.cian.ru/sale/flat/147462003/
# http://www.cian.ru/sale/flat/6685231/
# http://www.cian.ru/sale/flat/31641496/
# http://www.cian.ru/sale/flat/149402359/
# http://www.cian.ru/sale/flat/150729996/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/147502007/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/151065385/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/147023453/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/150608093/
# http://www.cian.ru/sale/flat/51251574/
# http://www.cian.ru/sale/flat/141527483/
# http://www.cian.ru/sale/flat/151037285/
# http://www.cian.ru/sale/flat/150171198/
# http://www.cian.ru/sale/flat/147023453/

# %%
import csv

def export_dict_list_to_csv(data, filename):
    with open(filename, 'w') as f:
        # Assuming that all dictionaries in the list have the same keys.
        headers = sorted([k for k, v in data[0].items()])
        csv_data = [headers]

        for d in data:
            csv_data.append([d[h] for h in headers])

        writer = csv.writer(f)
        writer.writerows(csv_data)

# %%
export_dict_list_to_csv(flats, "flats.csv")
